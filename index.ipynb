# %% [markdown]
# # Filtering Data with SQL - Lab

# %% [markdown]
# ## Introduction
#
# NASA wants to go to Mars! Before they build their rocket, NASA needs to track information about all of the planets in the Solar System. In this lab, you'll practice querying the database with various `SELECT` statements. This will include selecting different columns and implementing other SQL clauses like `WHERE` to return the data desired.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/learn-co-curriculum/dsc-filtering-lab-v2-4/master/images/planets.png" alt="image of solar system" width="600">

# %% [markdown]
# ## Objectives
#
# You will practice the following:
#
# * Retrieve a subset of records from a table using a `WHERE` clause
# * Filter results using conditional operators such as `BETWEEN`, `IS NULL`, and `LIKE`
# * Apply an aggregate function to the result of a filtered query

# %% [markdown]
# ## Connecting to the Database
#
# To get started, import `sqlite3` as well as `pandas` for conveniently displaying results. Then, connect to the SQLite database located at `planets.db`.

# %%
import pandas as pd
import sqlite3
# Establish a connection to your SQLite database
conn = sqlite3.connect('planets.db.') 
df
# Out:
#       name has_rings
# 0  Mercury        NO
# 1    Venus        NO
# 2    Earth        NO
# 3     Mars        NO
# 4  Jupiter        NO
# 5   Saturn       YES
# 6   Uranus       YES
# 7  Neptune       YES

# %% [markdown]
# ## Database Schema
#
# This database contains a single table, `planets`. This is the schema:
#
# ```
# CREATE TABLE planets (
#   id INTEGER PRIMARY KEY,
#   name TEXT,
#   color TEXT,
#   num_of_moons INTEGER,
#   mass REAL,
#   rings BOOLEAN
# );
# ```
#
# The data looks something like this:
#
# | id | name    | color      | num_of_moons | mass   | rings |
# | -- | ------- | ---------- | ------------ | ------ | ----- |
# | 1  | Mercury | gray       | 0            | 0.55   | FALSE |
# | 2  | Venus   | yellow     | 0            | 0.82   | FALSE |
# | 3  | Earth   | blue       | 1            | 1.00   | FALSE |
# | 4  | Mars    | red        | 2            | 0.11   | FALSE |
# | 5  | Jupiter | orange     | 67           | 317.90 | FALSE |
# | 6  | Saturn  | hazel      | 62           | 95.19  | TRUE  |
# | 7  | Uranus  | light blue | 27           | 14.54  | TRUE  |
# | 8  | Neptune | dark blue  | 14           | 17.15  | TRUE  |

# %% [markdown]
# ## SQL Queries
#
# Write SQL queries for each of the statements below using the same pandas wrapping syntax from the previous lesson.

# %% [markdown]
# ### 1. Select just the `name` and `color` of each planet

# %%
df = pd.read_sql("""
SELECT name, color
FROM Planets;
""", conn)
df
# Out:
#       name       color
# 0  Mercury        gray
# 1    Venus      yellow
# 2    Earth        blue
# 3     Mars         red
# 4  Jupiter      orange
# 5   Saturn       hazel
# 6   Uranus  light blue
# 7  Neptune   dark blue

# %% [markdown]
# ### 2. Select all columns for each planet whose `num_of_moons` is 0

# %%
df1 = pd.read_sql("""
SELECT num_of_moons = 0
FROM planets;
""", conn)
df
# Out:
#       name       color
# 0  Mercury        gray
# 1    Venus      yellow
# 2    Earth        blue
# 3     Mars         red
# 4  Jupiter      orange
# 5   Saturn       hazel
# 6   Uranus  light blue
# 7  Neptune   dark blue

# %% [markdown]
# ### 3. Select the `name` and `mass` of each planet whose `name` has exactly 7 letters

# %%
df2 = pd.read_sql("""
SELECT name, mass
FROM planets
WHERE LENGTH(name) = 7;
""", conn)
df
# Out:
#       name       color
# 0  Mercury        gray
# 1    Venus      yellow
# 2    Earth        blue
# 3     Mars         red
# 4  Jupiter      orange
# 5   Saturn       hazel
# 6   Uranus  light blue
# 7  Neptune   dark blue

# %% [markdown]
# ### 4. Select all columns for each planet whose `mass` is greater than 1.00

# %%
df = pd.read_sql("""
SELECT mass > 1.00
FROM planets;
""", conn)
df
# Out:
#    mass > 1.00
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
# 5            1
# 6            1
# 7            1

# %% [markdown]
# ### 5. Select the `name` and `mass` of each planet whose `mass` is less than or equal to 1.00

# %%
df = pd.read_sql("""
SELECT name, mass
FROM  planets
WHERE mass <= 1.00
""", conn)
df
# Out:
#       name  mass
# 0  Mercury  0.55
# 1    Venus  0.82
# 2    Earth  1.00
# 3     Mars  0.11

# %% [markdown]
# ### 6. Select the `name` and `mass` of each planet whose `mass` is between 0 and 50

# %%
df = pd.read_sql("""
SELECT name, mass
FROM planets
WHERE mass BETWEEN 0 AND 50;
""", conn)
df
# Out:
#       name   mass
# 0  Mercury   0.55
# 1    Venus   0.82
# 2    Earth   1.00
# 3     Mars   0.11
# 4   Uranus  14.54
# 5  Neptune  17.15

# %% [markdown]
# ### 7. Select all columns for planets that have at least one moon and a `mass` less than 1.00
#
# ***Hint:*** You can use `AND` to chain together two conditions in SQL, similar to `and` in Python

# %%
df = pd.read_sql("""
SELECT columns (*)
FROM planets
WHERE >=1 AND mass < 1.00;
""", conn)
df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\ERIC\anaconda3\envs\learn-env\Lib\site-packages\pandas\io\sql.py:2672, in SQLiteDatabase.execute(self, sql, params)
#    2671 try:
# -> 2672     cur.execute(sql, *args)
#    2673     return cur
#
# OperationalError: near ">=": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 df = pd.read_sql("""
#       2 SELECT columns (*)
#       3 FROM planets
#       4 WHERE >=1 AND mass < 1.00;
#       5 """, conn)
#       6 df
#
# File c:\Users\ERIC\anaconda3\envs\learn-env\Lib\site-packages\pandas\io\sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704 with pandasSQL_builder(con) as pandas_sql:
#     705     if isinstance(pandas_sql, SQLiteDatabase):
# --> 706         return pandas_sql.read_query(
#     707             sql,
#     708             index_col=index_col,
#     709             params=params,
#     710             coerce_float=coerce_float,
#     711             parse_dates=parse_dates,
#     712             chunksize=chunksize,
#     713             dtype_backend=dtype_backend,
#     714             dtype=dtype,
#     715         )
#     717     try:
#     718         _is_table_name = pandas_sql.has_table(sql)
#
# File c:\Users\ERIC\anaconda3\envs\learn-env\Lib\site-packages\pandas\io\sql.py:2736, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2725 def read_query(
#    2726     self,
#    2727     sql,
#    (...)
#    2734     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2735 ) -> DataFrame | Iterator[DataFrame]:
# -> 2736     cursor = self.execute(sql, params)
#    2737     columns = [col_desc[0] for col_desc in cursor.description]
#    2739     if chunksize is not None:
#
# File c:\Users\ERIC\anaconda3\envs\learn-env\Lib\site-packages\pandas\io\sql.py:2684, in SQLiteDatabase.execute(self, sql, params)
#    2681     raise ex from inner_exc
#    2683 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2684 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT columns (*)
# FROM planets
# WHERE >=1 AND mass < 1.00;
# ': near ">=": syntax error

# %% [markdown]
# ### 8. Select the `name` and `color` of planets that have a `color` containing the string "blue"

# %%
df = pd.read_sql("""
SELECT name, color
FROM planets
WHERE color LIKE '%blue%';
""", conn)
df
# Out:
#       name       color
# 0    Earth        blue
# 1   Uranus  light blue
# 2  Neptune   dark blue

# %% [markdown]
# ### 9. Select the count of planets that don't have rings as `planets_without_rings`
#
# Note: even though the schema states that `rings` is a `BOOLEAN` and the example table shows values `TRUE` and `FALSE`, SQLite does not actually support booleans natively. From the [documentation](https://www.sqlite.org/datatype3.html#boolean_datatype):
#
# > SQLite does not have a separate Boolean storage class. Instead, Boolean values are stored as integers 0 (false) and 1 (true).

# %%
df = pd.read_sql("""
SELECT COUNT (*) AS planets_without_rings
FROM  planets
WHERE rings = 1;
""", conn)
df
# Out:
#    planets_without_rings
# 0                      3

# %% [markdown]
# ### 10. Select the name of all planets, along with a value `has_rings` that returns "Yes" if the planet does have rings, and "No" if it does not

# %%
df = pd.read_sql("""
SELECT name,
   CASE
   WHEN rings = 1 THEN'YES'
   ELSE 'NO'
   END AS has_rings
   FROM planets;
   """, conn)
df
# Out:
#       name has_rings
# 0  Mercury        NO
# 1    Venus        NO
# 2    Earth        NO
# 3     Mars        NO
# 4  Jupiter        NO
# 5   Saturn       YES
# 6   Uranus       YES
# 7  Neptune       YES

# %% [markdown]
# Congratulations! NASA is one step closer to embarking upon its mission to Mars. In this lab, You practiced writing `SELECT` statements that query a single table to get specific information. You also used other clauses and specified column names to cherry-pick the data we wanted to retrieve.
